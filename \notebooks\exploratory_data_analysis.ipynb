# %% [markdown]
# <a href="https://colab.research.google.com/github/AIVIETNAM-AIO-ERICPHAM73/project-conquer-module-01/blob/main/%5Cnotebooks%5Cexploratory_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git status
# !git add .
# !git commit -m "thêm notebook eda"
# !git push origin main
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git
