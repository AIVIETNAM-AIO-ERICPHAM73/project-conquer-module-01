# %% [markdown]
# <a href="https://colab.research.google.com/github/AIVIETNAM-AIO-ERICPHAM73/project-conquer-module-01/blob/main/notebooks/exploratory_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/AIVIETNAM-AIO-ERICPHAM73/project-conquer-module-01.git
# %cd project-conquer-module-01
# !git config --global user.email "pvnghi9@gmail.com"
# !git config --global user.name "AIVIETNAM-AIO-ERICPHAM73"
# Out:
# Cloning into 'project-conquer-module-01'...
# remote: Enumerating objects: 34, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 34 (delta 10), reused 23 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (34/34), 5.76 KiB | 2.88 MiB/s, done.
# Resolving deltas: 100% (10/10), done.
# /content/project-conquer-module-01

# %%
# !git status
# !git add .
# !git commit -m "thêm notebook eda"
# !git push origin main
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# fatal: could not read Username for 'https://github.com': No such device or address
